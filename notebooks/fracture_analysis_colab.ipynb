# %% [markdown]
# # 🦴 Hybrid Fracture Analysis - Google Colab Edition
#
# Welcome! This notebook allows you to run the Fracture Analysis System using Google's free GPU power.
#
# ### Steps:
# 1.  **Run Cell 1**: To setup the environment.
# 2.  **Upload Data**: You will need to upload your 'data' folder (zipped) or use a sample.
# 3.  **Run Training**: Train the AI.
# 4.  **Run Inference**: Analyze new images.

# %%
# Step 1: Setup Environment
# Clone the repository (if you haven't already uploaded it manually)
# !git clone https://github.com/MS-SE-Forge/PatternRecognition_Hybrid-Fracture-Analysis-CNN.git
# %cd PatternRecognition_Hybrid-Fracture-Analysis-CNN

# Install dependencies
# !pip install torch torchvision opencv-python numpy scikit-image pillow

# %% [markdown]
# ### Step 2: Upload Your Data
# Please upload a zip file named `data.zip` containing your `train`, `val`, and `test` folders into the `PatternRecognition_Hybrid-Fracture-Analysis-CNN` folder on the left sidebar.
#
# Then run the cell below to unzip it.

# %%
# !unzip data.zip -d .

# %%
# Step 3: Train the Brain
# !python src/train.py

# %%
# Step 4: Run Analysis (Inference)
# Make sure you have some images in data/inference_input
# !python src/main.py
