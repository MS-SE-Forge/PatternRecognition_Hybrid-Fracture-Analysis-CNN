# %% [markdown]
# # 🦴 Hybrid Fracture Analysis - Google Colab Edition
#
# Welcome! This notebook allows you to run the Fracture Analysis System using Google's free GPU power.
#
# ### Steps:
# 1.  **Run Cell 1**: Connect to GitHub (Access Private Repo).
# 2.  **Run Training**: Train the AI.
# 3.  **Run Inference**: Analyze new images.

# %%
# Step 1: Setup & Connect to GitHub
import getpass
import os

# Check if we already cloned it
if not os.path.exists("PatternRecognition_Hybrid-Fracture-Analysis-CNN"):
    print("--- GITHUB AUTHENTICATION ---")
    print("Your repository looks PRIVATE. Google needs a password (Token) to verify it's you.")
    print("1. Go to https://github.com/settings/tokens")
    print("2. Generate a new token (Classic) with 'repo' checkbox ticked.")
    print("3. Paste it below and hit Enter.")
    print("-----------------------------")
    
    try:
        # Try public clone first
        # !git clone https://github.com/MS-SE-Forge/PatternRecognition_Hybrid-Fracture-Analysis-CNN.git
    except:
        # If failed, ask for token
        token = getpass.getpass("Paste your GitHub Token here: ")
        # !git clone https://{token}@github.com/MS-SE-Forge/PatternRecognition_Hybrid-Fracture-Analysis-CNN.git

# %cd PatternRecognition_Hybrid-Fracture-Analysis-CNN

# Install dependencies
# !pip install torch torchvision opencv-python numpy scikit-image pillow

# %%
# Step 2: Train the Brain
# !python src/train.py

# %%
# Step 3: Run Analysis (Inference)
# !python src/main.py
