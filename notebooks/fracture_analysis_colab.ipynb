# %% [markdown]
# # 🦴 Hybrid Fracture Analysis - Google Colab Edition
#
# Welcome! This notebook allows you to run the Fracture Analysis System using Google's free GPU power.
#
# ### Steps:
# 1.  **Run Cell 1**: Setup environment and fetch code + data from GitHub.
# 2.  **Run Training**: Train the AI using the data in the repository.
# 3.  **Run Inference**: Analyze new images.

# %%
# Step 1: Setup Environment & Fetch Data
# Clone the repository which INCLUDES the training data
# !git clone https://github.com/MS-SE-Forge/PatternRecognition_Hybrid-Fracture-Analysis-CNN.git
# %cd PatternRecognition_Hybrid-Fracture-Analysis-CNN

# Install dependencies
# !pip install torch torchvision opencv-python numpy scikit-image pillow

# %%
# Step 2: Train the Brain
# This will use the 'data' folder that came with the git repo
# !python src/train.py

# %%
# Step 3: Run Analysis (Inference)
# Specify a few test images if checking specific files, or just run the batch process
# !python src/main.py
